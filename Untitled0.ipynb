# %%
# !pip install ultralytics
from ultralytics import YOLO
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 15.7 MB/s eta 0:00:00
# ...
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# %%writefile augment.yaml
# # YOLOv8 custom augmentation file
# augment:
#   hsv_h: 0.015
#   hsv_s: 0.7
#   hsv_v: 0.4
#   degrees: 10            # rotation
#   translate: 0.1
#   scale: 0.5
#   shear: 0.2
#   perspective: 0.0005
#   flipud: 0.0
#   fliplr: 0.5
#   mosaic: 1.0
#   mixup: 0.1
#   copy_paste: 0.1       # simulating occlusion
# Out:
# Writing augment.yaml

# %%
# !pip install ultralytics
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="coco128.yaml",
    epochs=20,
    imgsz=640,
    batch=16
)
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 56.4 MB/s eta 0:00:00
# ...
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.3.237 🚀 Python-3.12.12 torch-2.9.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# ...

# %%
# !pip install ultralytics
from ultralytics import YOLO

model = YOLO("yolov8n-seg.pt")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 19.1 MB/s eta 0:00:00
# ...
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...

# %%
# !pip install ultralytics
from ultralytics import YOLO

# !wget https://ultralytics.com/assets/coco8-seg.zip
# !unzip -o coco8-seg.zip

model = YOLO("yolov8n-seg.pt")
model.train(data="coco8-seg.yaml", epochs=20, imgsz=640)

# Load the best trained model for prediction
model = YOLO("/content/runs/segment/train3/weights/best.pt")
# Run prediction on a sample image from the dataset
# Assuming 'bus.jpg' is present in 'coco8-seg/images/val'
results = model.predict(source="coco8-seg/images/val/bus.jpg", save=True, save_txt=False)
# Out:
# ...
# --2025-12-16 11:59:28--  https://ultralytics.com/assets/coco8-seg.zip
# Resolving ultralytics.com (ultralytics.com)... 198.202.211.1
# Connecting to ultralytics.com (ultralytics.com)|198.202.211.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://www.ultralytics.com/assets/coco8-seg.zip [following]
# --2025-12-16 11:59:28--  https://www.ultralytics.com/assets/coco8-seg.zip
# Resolving www.ultralytics.com (www.ultralytics.com)... 198.202.211.1, 2620:cb:2000::1
# Connecting to www.ultralytics.com (www.ultralytics.com)|198.202.211.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://github.com/ultralytics/assets/releases/download/v0.0.0/coco8-seg.zip [following]
# --2025-12-16 11:59:28--  https://github.com/ultralytics/assets/releases/download/v0.0.0/coco8-seg.zip
# Resolving github.com (github.com)... 140.82.116.4
# ...
